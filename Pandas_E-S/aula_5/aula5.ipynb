# %% [markdown]
# # Aula 5 - Leyendo banco de datos

# %% [markdown]
# ## **Creando un banco de datos local**

# %%
import sqlalchemy

# %%
from sqlalchemy import create_engine, MetaData, Table, inspect, text

# %%
engine = create_engine('sqlite:///:memory:')

# %% [markdown]
# ## **Escribiendo en un banco de datos**

# %%
import pandas as pd

# %%
archivo = "clientes_banco.csv"

# %%
datos = pd.read_csv(archivo)

# %%
datos.head()
# Out:
#    ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0     5008804    32    Nivel superior  Relación-estable             2.0
# 1     5008805    32    Nivel superior  Relación-estable             2.0
# 2     5008806    58  Nivel intermedio            Casado             2.0
# 3     5008808    52  Nivel intermedio           Soltero             1.0
# 4     5008809    52  Nivel intermedio           Soltero             1.0
#
#   Categoria_de_renta  Ocupacion  Años_empleado  Rendimiento_anual  \
# 0           Empleado       Otro           12.0           427500.0
# 1           Empleado       Otro           12.0           427500.0
# 2           Empleado  Seguridad            3.0           112500.0
# 3   Business Partner     Ventas            8.0           270000.0
# 4   Business Partner     Ventas            8.0           270000.0
#
#    Tiene_carro                  Vivienda
# 0          1.0    Departamento alquilado
# 1          1.0    Departamento alquilado
# 2          1.0  Casa/Departamento propio
# 3          0.0  Casa/Departamento propio
# 4          0.0  Casa/Departamento propio

# %%
datos.to_sql('clientes', engine, index=False)
# Out:
# 95896

# %%
inspector = inspect(engine)

# %%
print(inspector.get_table_names())
# Out:
# ['clientes']

# %% [markdown]
# ## **Leyendo una consulta SQL**

# %%
query = "SELECT * FROM clientes WHERE Categoria_de_renta = 'Empleado'"

# %%
empleados = pd.read_sql(sql=text(query), con = engine.connect())

# %%
empleados
# Out:
#        ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0         5008804    32    Nivel superior  Relación-estable             2.0
# 1         5008805    32    Nivel superior  Relación-estable             2.0
# 2         5008806    58  Nivel intermedio            Casado             2.0
# 3         5008815    46    Nivel superior            Casado             2.0
# 4         5112956    46    Nivel superior            Casado             2.0
# ...           ...   ...               ...               ...             ...
# 48726     5713924    51  Nivel intermedio           Soltero             1.0
# 48727     5713925    51  Nivel intermedio           Soltero             1.0
# 48728     5713927    51  Nivel intermedio           Soltero             1.0
# 48729     5713929    51  Nivel intermedio           Soltero             1.0
# 48730     5713930    51  Nivel intermedio           Soltero             1.0
#
#       Categoria_de_renta     Ocupacion  Años_empleado  Rendimiento_anual  \
# 0               Empleado          Otro           12.0           427500.0
# 1               Empleado          Otro           12.0           427500.0
# 2               Empleado     Seguridad            3.0           112500.0
# 3               Empleado  Contabilidad            2.0           270000.0
# 4               Empleado  Contabilidad            2.0           270000.0
# ...                  ...           ...            ...                ...
# 48726           Empleado          Otro            5.0           180000.0
# 48727           Empleado          Otro            5.0           180000.0
# 48728           Empleado          Otro            5.0           180000.0
# 48729           Empleado          Otro            5.0           180000.0
# 48730           Empleado          Otro            5.0           180000.0
#
#        Tiene_carro                  Vivienda
# 0              1.0    Departamento alquilado
# 1              1.0    Departamento alquilado
# 2              1.0  Casa/Departamento propio
# 3              1.0  Casa/Departamento propio
# 4              1.0  Casa/Departamento propio
# ...            ...                       ...
# 48726          0.0  Casa/Departamento propio
# 48727          0.0  Casa/Departamento propio
# 48728          0.0  Casa/Departamento propio
# 48729          0.0  Casa/Departamento propio
# 48730          0.0  Casa/Departamento propio
#
# [48731 rows x 11 columns]

# %%
empleados.to_sql('empleados', con = engine.connect(), index=False)
# Out:
# 48731

# %%
pd.read_sql_table('empleados', con = engine.connect())
# Out:
#        ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0         5008804    32    Nivel superior  Relación-estable             2.0
# 1         5008805    32    Nivel superior  Relación-estable             2.0
# 2         5008806    58  Nivel intermedio            Casado             2.0
# 3         5008815    46    Nivel superior            Casado             2.0
# 4         5112956    46    Nivel superior            Casado             2.0
# ...           ...   ...               ...               ...             ...
# 48726     5713924    51  Nivel intermedio           Soltero             1.0
# 48727     5713925    51  Nivel intermedio           Soltero             1.0
# 48728     5713927    51  Nivel intermedio           Soltero             1.0
# 48729     5713929    51  Nivel intermedio           Soltero             1.0
# 48730     5713930    51  Nivel intermedio           Soltero             1.0
#
#       Categoria_de_renta     Ocupacion  Años_empleado  Rendimiento_anual  \
# 0               Empleado          Otro           12.0           427500.0
# 1               Empleado          Otro           12.0           427500.0
# 2               Empleado     Seguridad            3.0           112500.0
# 3               Empleado  Contabilidad            2.0           270000.0
# 4               Empleado  Contabilidad            2.0           270000.0
# ...                  ...           ...            ...                ...
# 48726           Empleado          Otro            5.0           180000.0
# 48727           Empleado          Otro            5.0           180000.0
# 48728           Empleado          Otro            5.0           180000.0
# 48729           Empleado          Otro            5.0           180000.0
# 48730           Empleado          Otro            5.0           180000.0
#
#        Tiene_carro                  Vivienda
# 0              1.0    Departamento alquilado
# 1              1.0    Departamento alquilado
# 2              1.0  Casa/Departamento propio
# 3              1.0  Casa/Departamento propio
# 4              1.0  Casa/Departamento propio
# ...            ...                       ...
# 48726          0.0  Casa/Departamento propio
# 48727          0.0  Casa/Departamento propio
# 48728          0.0  Casa/Departamento propio
# 48729          0.0  Casa/Departamento propio
# 48730          0.0  Casa/Departamento propio
#
# [48731 rows x 11 columns]

# %%
pd.read_sql_table('empleados', con = engine.connect(), columns=['ID_Cliente', 'Grado_estudio', 'Rendimiento_anual'])
# Out:
#        ID_Cliente     Grado_estudio  Rendimiento_anual
# 0         5008804    Nivel superior           427500.0
# 1         5008805    Nivel superior           427500.0
# 2         5008806  Nivel intermedio           112500.0
# 3         5008815    Nivel superior           270000.0
# 4         5112956    Nivel superior           270000.0
# ...           ...               ...                ...
# 48726     5713924  Nivel intermedio           180000.0
# 48727     5713925  Nivel intermedio           180000.0
# 48728     5713927  Nivel intermedio           180000.0
# 48729     5713929  Nivel intermedio           180000.0
# 48730     5713930  Nivel intermedio           180000.0
#
# [48731 rows x 3 columns]

# %%
query = 'SELECT * FROM clientes'

# %%
pd.read_sql(sql=text(query), con = engine.connect())
# Out:
#        ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0         5008804    32    Nivel superior  Relación-estable             2.0
# 1         5008805    32    Nivel superior  Relación-estable             2.0
# 2         5008806    58  Nivel intermedio            Casado             2.0
# 3         5008808    52  Nivel intermedio           Soltero             1.0
# 4         5008809    52  Nivel intermedio           Soltero             1.0
# ...           ...   ...               ...               ...             ...
# 95891     5713925    51  Nivel intermedio           Soltero             1.0
# 95892     5713927    51  Nivel intermedio           Soltero             1.0
# 95893     5713929    51  Nivel intermedio           Soltero             1.0
# 95894     5713930    51  Nivel intermedio           Soltero             1.0
# 95895     5713931    51  Nivel intermedio           Soltero             NaN
#
#       Categoria_de_renta  Ocupacion  Años_empleado  Rendimiento_anual  \
# 0               Empleado       Otro           12.0           427500.0
# 1               Empleado       Otro           12.0           427500.0
# 2               Empleado  Seguridad            3.0           112500.0
# 3       Business Partner     Ventas            8.0           270000.0
# 4       Business Partner     Ventas            8.0           270000.0
# ...                  ...        ...            ...                ...
# 95891           Empleado       Otro            5.0           180000.0
# 95892           Empleado       Otro            5.0           180000.0
# 95893           Empleado       Otro            5.0           180000.0
# 95894           Empleado       Otro            5.0           180000.0
# 95895               None       None            NaN                NaN
#
#        Tiene_carro                  Vivienda
# 0              1.0    Departamento alquilado
# 1              1.0    Departamento alquilado
# 2              1.0  Casa/Departamento propio
# 3              0.0  Casa/Departamento propio
# 4              0.0  Casa/Departamento propio
# ...            ...                       ...
# 95891          0.0  Casa/Departamento propio
# 95892          0.0  Casa/Departamento propio
# 95893          0.0  Casa/Departamento propio
# 95894          0.0  Casa/Departamento propio
# 95895          NaN                      None
#
# [95896 rows x 11 columns]

# %%
#Borrando registros

from sqlalchemy.exc import SQLAlchemyError
query = 'DELETE FROM clientes WHERE ID_Cliente = 5008804'
try:
   r_set = engine.connect().execute(text(query))
except SQLAlchemyError as e:
    print(e)
else:
    print('Registro borrado:', r_set.rowcount)
# Out:
# Registro borrado: 1

# %%
pd.read_sql_table('clientes', con = engine.connect())
# Out:
#        ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0         5008805    32    Nivel superior  Relación-estable             2.0
# 1         5008806    58  Nivel intermedio            Casado             2.0
# 2         5008808    52  Nivel intermedio           Soltero             1.0
# 3         5008809    52  Nivel intermedio           Soltero             1.0
# 4         5008810    52  Nivel intermedio           Soltero             1.0
# ...           ...   ...               ...               ...             ...
# 95890     5713925    51  Nivel intermedio           Soltero             1.0
# 95891     5713927    51  Nivel intermedio           Soltero             1.0
# 95892     5713929    51  Nivel intermedio           Soltero             1.0
# 95893     5713930    51  Nivel intermedio           Soltero             1.0
# 95894     5713931    51  Nivel intermedio           Soltero             NaN
#
#       Categoria_de_renta  Ocupacion  Años_empleado  Rendimiento_anual  \
# 0               Empleado       Otro           12.0           427500.0
# 1               Empleado  Seguridad            3.0           112500.0
# 2       Business Partner     Ventas            8.0           270000.0
# 3       Business Partner     Ventas            8.0           270000.0
# 4       Business Partner     Ventas            8.0           270000.0
# ...                  ...        ...            ...                ...
# 95890           Empleado       Otro            5.0           180000.0
# 95891           Empleado       Otro            5.0           180000.0
# 95892           Empleado       Otro            5.0           180000.0
# 95893           Empleado       Otro            5.0           180000.0
# 95894               None       None            NaN                NaN
#
#        Tiene_carro                  Vivienda
# 0              1.0    Departamento alquilado
# 1              1.0  Casa/Departamento propio
# 2              0.0  Casa/Departamento propio
# 3              0.0  Casa/Departamento propio
# 4              0.0  Casa/Departamento propio
# ...            ...                       ...
# 95890          0.0  Casa/Departamento propio
# 95891          0.0  Casa/Departamento propio
# 95892          0.0  Casa/Departamento propio
# 95893          0.0  Casa/Departamento propio
# 95894          NaN                      None
#
# [95895 rows x 11 columns]

# %%
#Actualizando registros

query = 'UPDATE clientes SET Grado_estudio="Nivel superior" WHERE ID_Cliente = 5008808'
try:
   r_set = engine.connect().execute(text(query))
except SQLAlchemyError as e:
    print(e)
else:
    print('Registros actualizados:', r_set.rowcount)
# Out:
# Registros actualizados: 1

# %%
pd.read_sql_table('clientes', con = engine.connect())
# Out:
#        ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0         5008805    32    Nivel superior  Relación-estable             2.0
# 1         5008806    58  Nivel intermedio            Casado             2.0
# 2         5008808    52    Nivel superior           Soltero             1.0
# 3         5008809    52  Nivel intermedio           Soltero             1.0
# 4         5008810    52  Nivel intermedio           Soltero             1.0
# ...           ...   ...               ...               ...             ...
# 95890     5713925    51  Nivel intermedio           Soltero             1.0
# 95891     5713927    51  Nivel intermedio           Soltero             1.0
# 95892     5713929    51  Nivel intermedio           Soltero             1.0
# 95893     5713930    51  Nivel intermedio           Soltero             1.0
# 95894     5713931    51  Nivel intermedio           Soltero             NaN
#
#       Categoria_de_renta  Ocupacion  Años_empleado  Rendimiento_anual  \
# 0               Empleado       Otro           12.0           427500.0
# 1               Empleado  Seguridad            3.0           112500.0
# 2       Business Partner     Ventas            8.0           270000.0
# 3       Business Partner     Ventas            8.0           270000.0
# 4       Business Partner     Ventas            8.0           270000.0
# ...                  ...        ...            ...                ...
# 95890           Empleado       Otro            5.0           180000.0
# 95891           Empleado       Otro            5.0           180000.0
# 95892           Empleado       Otro            5.0           180000.0
# 95893           Empleado       Otro            5.0           180000.0
# 95894               None       None            NaN                NaN
#
#        Tiene_carro                  Vivienda
# 0              1.0    Departamento alquilado
# 1              1.0  Casa/Departamento propio
# 2              0.0  Casa/Departamento propio
# 3              0.0  Casa/Departamento propio
# 4              0.0  Casa/Departamento propio
# ...            ...                       ...
# 95890          0.0  Casa/Departamento propio
# 95891          0.0  Casa/Departamento propio
# 95892          0.0  Casa/Departamento propio
# 95893          0.0  Casa/Departamento propio
# 95894          NaN                      None
#
# [95895 rows x 11 columns]

# %%
inspector = inspect(engine)
print(inspector.get_table_names())
# Out:
# ['clientes', 'empleados']
